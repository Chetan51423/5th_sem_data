# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread(r"C:\Users\cheta\Downloads\peacock.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread(r"C:\Users\cheta\Downloads\tiger.jpg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
print(img1.shape)
print(img2.shape)

im1 = img1[:, :640]
im2 = img2[:615, :]

AND = cv2.bitwise_and(im1, im2)

plt.imshow(im1)
plt.show()
plt.imshow(im2)
plt.show()
plt.imshow(AND)
plt.show()
# Out:
# (177, 284, 3)
# (194, 259, 3)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 11
#       8 im1 = img1[:, :640]
#       9 im2 = img2[:615, :]
# ---> 11 AND = cv2.bitwise_and(im1, im2)
#      13 plt.imshow(im1)
#      14 plt.show()
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'cv::binary_op'

# %%
img1 = cv2.imread(r"C:\Users\cheta\Downloads\peacock.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread(r"C:\Users\cheta\Downloads\tiger.jpg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
print(img1.shape)
print(img2.shape)
# Out:
# (177, 284, 3)
# (194, 259, 3)

# %%
im1 = img1[:, :194]
im2 = img2[:177, :]

AND = cv2.bitwise_and(im1, im2)

plt.imshow(im1)
plt.show()
plt.imshow(im2)
plt.show()
plt.imshow(AND)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 4
#       1 im1 = img1[:, :194]
#       2 im2 = img2[:177, :]
# ----> 4 AND = cv2.bitwise_and(im1, im2)
#       6 plt.imshow(im1)
#       7 plt.show()
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'cv::binary_op'

# %%
im1 = img1[:, :640]
im2 = img2[:615, :]

AND = cv2.bitwise_and(im1, im2)

plt.imshow(im1)
plt.show()
plt.imshow(im2)
plt.show()
plt.imshow(AND)
plt.show()

# %%
img1 = cv2.imread(r"C:\Users\cheta\Downloads\peacock.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread(r"C:\Users\cheta\Downloads\peacock.jpg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
print(img1.shape)
print(img2.shape)
# Out:
# (177, 284, 3)
# (177, 284, 3)

# %%
# im1 = img1[:, :177]
# im2 = img2[:177, :]

AND = cv2.bitwise_and(im1, im2)

plt.imshow(im1)
plt.show()
plt.imshow(im2)
plt.show()
plt.imshow(AND)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 4
#       1 im1 = img1[:, :177]
#       2 im2 = img2[:177, :]
# ----> 4 AND = cv2.bitwise_and(im1, im2)
#       6 plt.imshow(im1)
#       7 plt.show()
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'cv::binary_op'

# %%
AND = cv2.bitwise_and(im1, im2)

plt.imshow(im1)
plt.show()
plt.imshow(im2)
plt.show()
plt.imshow(AND)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 AND = cv2.bitwise_and(im1, im2)
#       3 plt.imshow(im1)
#       4 plt.show()
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'cv::binary_op'

# %%
img1 = cv2.imread(r"C:\Users\cheta\Downloads\peacock.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread(r"C:\Users\cheta\Downloads\tiger.jpg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
print(img1.shape)
print(img2.shape)

im1 = img1[:, :259]
im2 = img2[:177, :]

AND = cv2.bitwise_and(im1, im2)

plt.imshow(im1)
plt.show()
plt.imshow(im2)
plt.show()
plt.imshow(AND)
plt.show()
# Out:
# (177, 284, 3)
# (194, 259, 3)

# %%
img1 = cv2.imread(r"C:\Users\cheta\Downloads\peacock.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread(r"C:\Users\cheta\Downloads\tiger.jpg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

im1 = img1[:, :259]
im2 = img2[:177, :]

OR = cv2.bitwise_or(im1, im2)

plt.imshow(im1)
plt.show()
plt.imshow(im2)
plt.show()
plt.imshow(OR)
plt.show()

# %%
img1 = cv2.imread(r"C:\Users\cheta\Downloads\peacock.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread(r"C:\Users\cheta\Downloads\tiger.jpg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

im1 = img1[:177, :259]
im2 = img2[:177, :259]

XOR = cv2.bitwise_xor(im1, im2)

plt.imshow(im1)
plt.show()
plt.imshow(im2)
plt.show()
plt.imshow(OR)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 2
#       1 img1 = cv2.imread(r"C:\Users\cheta\Downloads\peacock.jpg")
# ----> 2 img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
#       3 img2 = cv2.imread(r"C:\Users\cheta\Downloads\tiger.jpg")
#       4 img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
img1 = cv2.imread(r"C:\Users\cheta\Downloads\peacock.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

NOT = cv2.bitwise_not(img1)

plt.imshow(img1)
plt.show()
plt.imshow(NOT)
plt.show()
