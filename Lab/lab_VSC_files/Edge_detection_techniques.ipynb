# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def high_pass(path):
    
    kernel = np.array([[-1, -1, -1],
                       [-1, 8, -1],
                       [-1, -1, -1]])

    
    # another kernal without 1/9
    out = cv2.filter2D(src=image, ddepth=-10, kernel=kernel)

    plt.imshow(image, 'gray')
    plt.title('Input Image')
    plt.show() 
    
    plt.imshow(out, 'gray')
    plt.title('High Pass Filter')
    plt.show()

# %%
image = cv2.imread(r"C:\Users\cheta\Downloads\sunset.jpeg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
x,y = gray.shape[:2]

plt.imshow(gray,'gray')
plt.title('Original Image')
plt.show()

# %%
high_pass(gray)

# %%
def sobel_kernel_verticle(path):
    
    kernel = np.array([[1, 0, -1],
                       [2, 0, -2],
                       [1, 0, -1]])

    
    # another kernal without 1/9
    out = cv2.filter2D(src=image, ddepth=-5, kernel=kernel)

    plt.imshow(image, 'gray')
    plt.title('Input Image')
    plt.show() 
    
    plt.imshow(out, 'gray')
    plt.title('High Pass Filter')
    plt.show()

# %%
image = cv2.imread(r"C:\Users\cheta\Downloads\sunset.jpeg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
x,y = gray.shape[:2]

plt.imshow(gray,'gray')
plt.title('Original Image')
plt.show()

# %%
sobel_kernel(gray)

# %%
def sobel_kernel_horizontal(path):
    
    kernel = np.array([[1, 2, 1],
                       [0, 0, 0],
                       [-1, -2, -1]])

    
    # another kernal without 1/9
    out = cv2.filter2D(src=image, ddepth=-5, kernel=kernel)

    plt.imshow(image, 'gray')
    plt.title('Input Image')
    plt.show() 
    
    plt.imshow(out, 'gray')
    plt.title('High Pass Filter')
    plt.show()

# %%
image = cv2.imread(r"C:\Users\cheta\Downloads\sunset.jpeg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
x,y = gray.shape[:2]

plt.imshow(gray,'gray')
plt.title('Original Image')
plt.show()

# %%
sobel_kernel_horizontal(gray)

# %%
def robert_kernel(path):
    
    kernel = np.array([[1, 0],
                       [0, 1]])

    
    # another kernal without 1/9
    out = cv2.filter2D(src=image, ddepth=-5, kernel=kernel)

    plt.imshow(image, 'gray')
    plt.title('Input Image')
    plt.show() 
    
    plt.imshow(out, 'gray')
    plt.title('High Pass Filter')
    plt.show()

# %%
image = cv2.imread(r"C:\Users\cheta\Downloads\sunset.jpeg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
x,y = gray.shape[:2]

plt.imshow(gray,'gray')
plt.title('Original Image')
plt.show()

# %%
robert_kernel(gray)

# %%
Canny Edge detection



#import cv2
#import numpy as np

# Load the input image
#img = cv2.imread("input.jpg", 0)

# Perform Gaussian blur to remove noise
img = cv2.GaussianBlur(gray, (5,5), 0)

# Perform Canny edge detection
edges = cv2.Canny(img, 100, 200)

# Show the result
cv2.imshow("Canny Edge Detection", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
