# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
print("1. Addition\n2. Subtraction\n3. Multiplication\n4. Division\n")
# Out:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division

# %%
path = input("Enter image name with path: ")
img = cv2.imread(path, 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

print(img.shape)
print(img) # elements

width = 10
height = 10 
dim = (width, height)
  
# resize image
resized = cv2.resize(img, dim)

print(resized.shape)
print(resized)

plt.imshow(resized,cmap='gray')
# Out:
# (177, 284)
# [[136 137 139 ... 102  98  94]
#  [139 141 142 ... 101  97  93]
#  [145 146 147 ...  99  95  92]
#  ...
#  [ 60  61  62 ...  25  63 116]
#  [ 57  58  61 ...  63  78 136]
#  [ 53  56  60 ...  34 107  86]]
# (10, 10)
# [[134 146 130 122 140 117 113  72  99 102]
#  [124 188 155 159 111 134  98  97 113 123]
#  [118 122 227  90 118 126 107 106  94  92]
#  [144 152  22  40  34  79  52  81  82  71]
#  [109  90  82 153 193 142 186  37  58  46]
#  [110 111  83  32 117 114 210 223  28  59]
#  [118  59  72  17  59 181 175 189 130 138]
#  [ 84  75  59  12  49  67 174 117  98 131]
#  [220 207  32  13  32  33 103  41 110  93]
#  [ 86  87 139  71 134  24 199  58 147 129]]

# %%
k = int(input("Enter intensity of 2nd img pixels: "))
M = np.ones(resized.shape, dtype="uint8") * k

print(resized)

print(M)


add1 = cv2.add(resized, M)

add2 = resized + M

print("The addition with CV2", add1)


print("The addition with simple operator", add2)

print("Shape of input image", resized.shape)

#plt.imshow(resized,cmap='gray')
#plt.show()

plt.imshow(resized, cmap='gray')
plt.show()


plt.imshow(add1, cmap='gray')
plt.show()

plt.imshow(add2,cmap='gray')
plt.show()
# Out:
# [[134 146 130 122 140 117 113  72  99 102]
#  [124 188 155 159 111 134  98  97 113 123]
#  [118 122 227  90 118 126 107 106  94  92]
#  [144 152  22  40  34  79  52  81  82  71]
#  [109  90  82 153 193 142 186  37  58  46]
#  [110 111  83  32 117 114 210 223  28  59]
#  [118  59  72  17  59 181 175 189 130 138]
#  [ 84  75  59  12  49  67 174 117  98 131]
#  [220 207  32  13  32  33 103  41 110  93]
#  [ 86  87 139  71 134  24 199  58 147 129]]
# [[100 100 100 100 100 100 100 100 100 100]
#  [100 100 100 100 100 100 100 100 100 100]
#  [100 100 100 100 100 100 100 100 100 100]
#  [100 100 100 100 100 100 100 100 100 100]
#  [100 100 100 100 100 100 100 100 100 100]
#  [100 100 100 100 100 100 100 100 100 100]
#  [100 100 100 100 100 100 100 100 100 100]
#  [100 100 100 100 100 100 100 100 100 100]
#  [100 100 100 100 100 100 100 100 100 100]
#  [100 100 100 100 100 100 100 100 100 100]]
# The addition with CV2 [[234 246 230 222 240 217 213 172 199 202]
#  [224 255 255 255 211 234 198 197 213 223]
#  [218 222 255 190 218 226 207 206 194 192]
#  [244 252 122 140 134 179 152 181 182 171]
#  [209 190 182 253 255 242 255 137 158 146]
#  [210 211 183 132 217 214 255 255 128 159]
#  [218 159 172 117 159 255 255 255 230 238]
#  [184 175 159 112 149 167 255 217 198 231]
#  [255 255 132 113 132 133 203 141 210 193]
#  [186 187 239 171 234 124 255 158 247 229]]
# The addition with simple operator [[234 246 230 222 240 217 213 172 199 202]
#  [224  32 255   3 211 234 198 197 213 223]
#  [218 222  71 190 218 226 207 206 194 192]
#  [244 252 122 140 134 179 152 181 182 171]
#  [209 190 182 253  37 242  30 137 158 146]
#  [210 211 183 132 217 214  54  67 128 159]
#  [218 159 172 117 159  25  19  33 230 238]
#  [184 175 159 112 149 167  18 217 198 231]
#  [ 64  51 132 113 132 133 203 141 210 193]
#  [186 187 239 171 234 124  43 158 247 229]]
# Shape of input image (10, 10)

# %%
path = input("Enter image name with path: ")
img = cv2.imread(path, 1)
#img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


print(img.shape)
print(img)


width = 10
height = 10 
dim = (width, height)
  
# resize image
resized = cv2.resize(img, dim)

print(resized.shape)
print(resized)

plt.imshow(resized)
# Out:
# (177, 284, 3)
# [[[122 152  90]
#   [123 153  89]
#   [125 156  86]
#   ...
#   [ 77 124  56]
#   [ 73 120  50]
#   [ 69 116  46]]
#
#  [[125 155  93]
#   [127 158  91]
#   [128 159  89]
#   ...
#   [ 76 123  53]
#   [ 72 119  47]
#   [ 68 115  43]]
#
#  [[130 162  97]
#   [131 163  96]
#   [132 165  94]
#   ...
#   [ 72 123  48]
#   [ 68 119  44]
#   [ 65 116  41]]
#
#  ...
#
#  [[ 43  73  37]
#   [ 44  74  38]
#   [ 45  75  39]
#   ...
#   [ 14  32  20]
#   [ 52  70  58]
#   [103 123 111]]
#
#  [[ 39  70  38]
#   [ 40  71  39]
#   [ 43  74  42]
#   ...
#   [ 49  71  58]
#   [ 64  86  73]
#   [122 144 131]]
#
#  [[ 36  64  39]
#   [ 39  67  42]
#   [ 43  72  44]
#   ...
#   [ 23  41  29]
#   [ 96 114 102]
#   [ 75  93  81]]]
# (10, 10, 3)
# [[[112 158  61]
#   [132 164  90]
#   [103 152  86]
#   [ 92 152  54]
#   [119 160  93]
#   [ 96 137  69]
#   [ 97 129  73]
#   [ 59  84  43]
#   [ 74 122  43]
#   [ 74 128  42]]
#
#  [[102 143  83]
#   [178 198 162]
#   [132 170 134]
#   [145 173 126]
#   [ 97 130  52]
#   [106 156  96]
#   [ 71 125  29]
#   [ 75 116  61]
#   [ 86 132  85]
#   [ 94 143  92]]
#
#  [[ 96 136  87]
#   [ 98 140  91]
#   [227 228 222]
#   [ 69 111  39]
#   [100 134  83]
#   [ 97 150  82]
#   [ 80 130  59]
#   [ 71 135  50]
#   [ 65 117  58]
#   [ 65 114  51]]
#
#  [[124 159 122]
#   [157 152 141]
#   [ 14  25  24]
#   [  5  51  74]
#   [ 17  42  40]
#   [ 40  98  87]
#   [ 42  62  29]
#   [ 67  97  36]
#   [ 57 101  52]
#   [ 58  84  40]]
#
#  [[ 86 135  35]
#   [ 68 111  40]
#   [ 32  82 212]
#   [126 149 251]
#   [195 193 188]
#   [141 142 138]
#   [167 195 187]
#   [ 30  41  35]
#   [ 41  72  32]
#   [ 35  54  35]]
#
#  [[ 81 136  54]
#   [ 80 135  71]
#   [ 42  79 205]
#   [ 14  33  69]
#   [107 120 130]
#   [102 119 122]
#   [205 213 210]
#   [221 228 209]
#   [  9  36  34]
#   [ 56  65  38]]
#
#  [[ 86 142  77]
#   [ 26  54 167]
#   [ 34  68 192]
#   [ 10  15  50]
#   [ 50  61  72]
#   [180 180 188]
#   [171 176 179]
#   [193 189 180]
#   [ 93 152 109]
#   [163 134  90]]
#
#  [[ 59 104  47]
#   [ 48  85  93]
#   [ 28  54 163]
#   [ 16   8  23]
#   [ 26  45 127]
#   [ 67  69  58]
#   [175 174 172]
#   [118 117 115]
#   [ 52 128  67]
#   [ 70 164 119]]
#
#  [[227 220 197]
#   [211 208 191]
#   [ 21  29  78]
#   [  9  12  24]
#   [ 29  30  50]
#   [ 28  36  33]
#   [105 103 101]
#   [ 42  41  39]
#   [107 115  94]
#   [ 65 109  86]]
#
#  [[ 94  91  41]
#   [ 95  90  51]
#   [148 139 114]
#   [ 77  72  49]
#   [177 120  91]
#   [ 17  25  35]
#   [200 198 201]
#   [ 59  57  60]
#   [150 146 145]
#   [ 95 150 117]]]

# %%
k = int(input("Enter intensity of 2nd img pixels: "))
M = np.ones(resized.shape, dtype="uint8") * k

print(resized)

print(M)


add1 = cv2.add(resized, M)

add2 = resized + M

print("The addition with CV2", add1)


print("The addition with simple operator", add2)

print("Shape of input image", resized.shape)

#plt.imshow(resized,cmap='gray')
#plt.show()

plt.imshow(resized)
plt.show()


plt.imshow(add1)
plt.show()

plt.imshow(add2)
plt.show()
# Out:
# [[[112 158  61]
#   [132 164  90]
#   [103 152  86]
#   [ 92 152  54]
#   [119 160  93]
#   [ 96 137  69]
#   [ 97 129  73]
#   [ 59  84  43]
#   [ 74 122  43]
#   [ 74 128  42]]
#
#  [[102 143  83]
#   [178 198 162]
#   [132 170 134]
#   [145 173 126]
#   [ 97 130  52]
#   [106 156  96]
#   [ 71 125  29]
#   [ 75 116  61]
#   [ 86 132  85]
#   [ 94 143  92]]
#
#  [[ 96 136  87]
#   [ 98 140  91]
#   [227 228 222]
#   [ 69 111  39]
#   [100 134  83]
#   [ 97 150  82]
#   [ 80 130  59]
#   [ 71 135  50]
#   [ 65 117  58]
#   [ 65 114  51]]
#
#  [[124 159 122]
#   [157 152 141]
#   [ 14  25  24]
#   [  5  51  74]
#   [ 17  42  40]
#   [ 40  98  87]
#   [ 42  62  29]
#   [ 67  97  36]
#   [ 57 101  52]
#   [ 58  84  40]]
#
#  [[ 86 135  35]
#   [ 68 111  40]
#   [ 32  82 212]
#   [126 149 251]
#   [195 193 188]
#   [141 142 138]
#   [167 195 187]
#   [ 30  41  35]
#   [ 41  72  32]
#   [ 35  54  35]]
#
#  [[ 81 136  54]
#   [ 80 135  71]
#   [ 42  79 205]
#   [ 14  33  69]
#   [107 120 130]
#   [102 119 122]
#   [205 213 210]
#   [221 228 209]
#   [  9  36  34]
#   [ 56  65  38]]
#
#  [[ 86 142  77]
#   [ 26  54 167]
#   [ 34  68 192]
#   [ 10  15  50]
#   [ 50  61  72]
#   [180 180 188]
#   [171 176 179]
#   [193 189 180]
#   [ 93 152 109]
#   [163 134  90]]
#
#  [[ 59 104  47]
#   [ 48  85  93]
#   [ 28  54 163]
#   [ 16   8  23]
#   [ 26  45 127]
#   [ 67  69  58]
#   [175 174 172]
#   [118 117 115]
#   [ 52 128  67]
#   [ 70 164 119]]
#
#  [[227 220 197]
#   [211 208 191]
#   [ 21  29  78]
#   [  9  12  24]
#   [ 29  30  50]
#   [ 28  36  33]
#   [105 103 101]
#   [ 42  41  39]
#   [107 115  94]
#   [ 65 109  86]]
#
#  [[ 94  91  41]
#   [ 95  90  51]
#   [148 139 114]
#   [ 77  72  49]
#   [177 120  91]
#   [ 17  25  35]
#   [200 198 201]
#   [ 59  57  60]
#   [150 146 145]
#   [ 95 150 117]]]
# [[[100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]]
#
#  [[100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]]
#
#  [[100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]]
#
#  [[100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]]
#
#  [[100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]]
#
#  [[100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]]
#
#  [[100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]]
#
#  [[100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]]
#
#  [[100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]]
#
#  [[100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]
#   [100 100 100]]]
# The addition with CV2 [[[212 255 161]
#   [232 255 190]
#   [203 252 186]
#   [192 252 154]
#   [219 255 193]
#   [196 237 169]
#   [197 229 173]
#   [159 184 143]
#   [174 222 143]
#   [174 228 142]]
#
#  [[202 243 183]
#   [255 255 255]
#   [232 255 234]
#   [245 255 226]
#   [197 230 152]
#   [206 255 196]
#   [171 225 129]
#   [175 216 161]
#   [186 232 185]
#   [194 243 192]]
#
#  [[196 236 187]
#   [198 240 191]
#   [255 255 255]
#   [169 211 139]
#   [200 234 183]
#   [197 250 182]
#   [180 230 159]
#   [171 235 150]
#   [165 217 158]
#   [165 214 151]]
#
#  [[224 255 222]
#   [255 252 241]
#   [114 125 124]
#   [105 151 174]
#   [117 142 140]
#   [140 198 187]
#   [142 162 129]
#   [167 197 136]
#   [157 201 152]
#   [158 184 140]]
#
#  [[186 235 135]
#   [168 211 140]
#   [132 182 255]
#   [226 249 255]
#   [255 255 255]
#   [241 242 238]
#   [255 255 255]
#   [130 141 135]
#   [141 172 132]
#   [135 154 135]]
#
#  [[181 236 154]
#   [180 235 171]
#   [142 179 255]
#   [114 133 169]
#   [207 220 230]
#   [202 219 222]
#   [255 255 255]
#   [255 255 255]
#   [109 136 134]
#   [156 165 138]]
#
#  [[186 242 177]
#   [126 154 255]
#   [134 168 255]
#   [110 115 150]
#   [150 161 172]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [193 252 209]
#   [255 234 190]]
#
#  [[159 204 147]
#   [148 185 193]
#   [128 154 255]
#   [116 108 123]
#   [126 145 227]
#   [167 169 158]
#   [255 255 255]
#   [218 217 215]
#   [152 228 167]
#   [170 255 219]]
#
#  [[255 255 255]
#   [255 255 255]
#   [121 129 178]
#   [109 112 124]
#   [129 130 150]
#   [128 136 133]
#   [205 203 201]
#   [142 141 139]
#   [207 215 194]
#   [165 209 186]]
#
#  [[194 191 141]
#   [195 190 151]
#   [248 239 214]
#   [177 172 149]
#   [255 220 191]
#   [117 125 135]
#   [255 255 255]
#   [159 157 160]
#   [250 246 245]
#   [195 250 217]]]
# The addition with simple operator [[[212   2 161]
#   [232   8 190]
#   [203 252 186]
#   [192 252 154]
#   [219   4 193]
#   [196 237 169]
#   [197 229 173]
#   [159 184 143]
#   [174 222 143]
#   [174 228 142]]
#
#  [[202 243 183]
#   [ 22  42   6]
#   [232  14 234]
#   [245  17 226]
#   [197 230 152]
#   [206   0 196]
#   [171 225 129]
#   [175 216 161]
#   [186 232 185]
#   [194 243 192]]
#
#  [[196 236 187]
#   [198 240 191]
#   [ 71  72  66]
#   [169 211 139]
#   [200 234 183]
#   [197 250 182]
#   [180 230 159]
#   [171 235 150]
#   [165 217 158]
#   [165 214 151]]
#
#  [[224   3 222]
#   [  1 252 241]
#   [114 125 124]
#   [105 151 174]
#   [117 142 140]
#   [140 198 187]
#   [142 162 129]
#   [167 197 136]
#   [157 201 152]
#   [158 184 140]]
#
#  [[186 235 135]
#   [168 211 140]
#   [132 182  56]
#   [226 249  95]
#   [ 39  37  32]
#   [241 242 238]
#   [ 11  39  31]
#   [130 141 135]
#   [141 172 132]
#   [135 154 135]]
#
#  [[181 236 154]
#   [180 235 171]
#   [142 179  49]
#   [114 133 169]
#   [207 220 230]
#   [202 219 222]
#   [ 49  57  54]
#   [ 65  72  53]
#   [109 136 134]
#   [156 165 138]]
#
#  [[186 242 177]
#   [126 154  11]
#   [134 168  36]
#   [110 115 150]
#   [150 161 172]
#   [ 24  24  32]
#   [ 15  20  23]
#   [ 37  33  24]
#   [193 252 209]
#   [  7 234 190]]
#
#  [[159 204 147]
#   [148 185 193]
#   [128 154   7]
#   [116 108 123]
#   [126 145 227]
#   [167 169 158]
#   [ 19  18  16]
#   [218 217 215]
#   [152 228 167]
#   [170   8 219]]
#
#  [[ 71  64  41]
#   [ 55  52  35]
#   [121 129 178]
#   [109 112 124]
#   [129 130 150]
#   [128 136 133]
#   [205 203 201]
#   [142 141 139]
#   [207 215 194]
#   [165 209 186]]
#
#  [[194 191 141]
#   [195 190 151]
#   [248 239 214]
#   [177 172 149]
#   [ 21 220 191]
#   [117 125 135]
#   [ 44  42  45]
#   [159 157 160]
#   [250 246 245]
#   [195 250 217]]]
# Shape of input image (10, 10, 3)

# %%
path = input("Enter image name with path: ")
img = cv2.imread(path, 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
k = int(input("Enter intensity of 2nd img pixels: "))
M = np.ones(img.shape, dtype="uint8") * k

sub = cv2.subtract(img, M)

plt.imshow(img)
plt.show()
plt.imshow(sub)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       2 img = cv2.imread(path, 1)
#       3 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ----> 5 k = int(input("Enter intensity of 2nd img pixels: "))
#       6 M = np.ones(img.shape, dtype="uint8") * k
#       8 sub = cv2.subtract(img, M)
#
# ValueError: invalid literal for int() with base 10: 'C:\\Users\\cheta\\Downloads\\peacock.jpg'

# %%
path = input("Enter image name with path: ")
img = cv2.imread(path, 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
k = int(input("Enter intensity of 2nd img pixels: "))
M = np.ones(img.shape, dtype="uint8") * k

sub = cv2.subtract(img, M)

plt.imshow(img)
plt.show()
plt.imshow(sub)
plt.show()

# %%
path = input("Enter image name with path: ")
img = cv2.imread(path, 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
k = int(input("Enter intensity of 2nd img pixels: "))
M = np.ones(img.shape, dtype="uint8") * k

mul = cv2.multiply(img, M)

plt.imshow(img)
plt.show()
plt.imshow(mul)
plt.show()

# %%
path = input("Enter image name with path: ")
img = cv2.imread(path, 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
k = int(input("Enter intensity of 2nd img pixels: "))
M = np.ones(img.shape, dtype="uint8") * k

div = cv2.divide(img, M)

plt.imshow(img)
plt.show()
plt.imshow(div)
plt.show()
